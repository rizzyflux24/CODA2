# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objects as go
from plotly import express as px

# %%
file_path = '2024_Round_1.csv'
df_josaaR1 = pd.read_csv(file_path)
df_josaaR1['Institute'] = df_josaaR1['Institute'].str.replace(r'\s+', ' ', regex=True)
df_josaaR1
# Out:
#                                         Institute  \
# 0      Indian Institute of Technology Bhubaneswar
# 1      Indian Institute of Technology Bhubaneswar
# 2      Indian Institute of Technology Bhubaneswar
# 3      Indian Institute of Technology Bhubaneswar
# 4      Indian Institute of Technology Bhubaneswar
# ...                                           ...
# 11682                                CU Jharkhand
# 11683                                CU Jharkhand
# 11684                                CU Jharkhand
# 11685                                CU Jharkhand
# 11686                                CU Jharkhand
#
#                                    Academic Program Name Quota      Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI           OPEN
# 1      Civil Engineering (4 Years, Bachelor of Techno...    AI           OPEN
# 2      Civil Engineering (4 Years, Bachelor of Techno...    AI            EWS
# ...

# %%
df_josaaR1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11687 entries, 0 to 11686
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              11687 non-null  object
#  1   Academic Program Name  11687 non-null  object
#  2   Quota                  11687 non-null  object
#  3   Seat Type              11687 non-null  object
#  4   Gender                 11687 non-null  object
#  5   Opening Rank           11687 non-null  object
#  6   Closing Rank           11687 non-null  object
# dtypes: object(7)
# memory usage: 639.3+ KB

# %%
filtered_df = df_josaaR1[(df_josaaR1['Quota'] == 'AI') & (df_josaaR1['Seat Type'] == 'OPEN') & (df_josaaR1['Gender'] == 'Gender-Neutral')]
filtered_df
# Out:
#                                         Institute  \
# 0      Indian Institute of Technology Bhubaneswar
# 10     Indian Institute of Technology Bhubaneswar
# 23     Indian Institute of Technology Bhubaneswar
# 34     Indian Institute of Technology Bhubaneswar
# 45     Indian Institute of Technology Bhubaneswar
# ...                                           ...
# 11652       Gati Shakti Vishwavidyalaya, Vadodara
# 11661                                CU Jharkhand
# 11667                                CU Jharkhand
# 11674                                CU Jharkhand
# 11680                                CU Jharkhand
#
#                                    Academic Program Name Quota Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 10     Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 23     Electrical Engineering (4 Years, Bachelor of T...    AI      OPEN
# ...

# %%
iit_fil_df = filtered_df[filtered_df['Institute'].str.contains('Indian institute of Technology', case=False)]
nit_fil_df = filtered_df[filtered_df['Institute'].str.contains('National Institute of Technology', case=False)]
gftis_fil_df = filtered_df[~filtered_df['Institute'].str.contains('Indian institute of technology|national institute of technology', case=False)]
nit_fil_df,
# Out:
# (Empty DataFrame
#  Columns: [Institute, Academic Program Name, Quota, Seat Type, Gender, Opening Rank, Closing Rank]
#  Index: [],)

# %%
iit_fil_df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 10    Indian Institute of Technology Bhubaneswar
# 23    Indian Institute of Technology Bhubaneswar
# 34    Indian Institute of Technology Bhubaneswar
# 45    Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 3036      Indian Institute of Technology Dharwad
# 3048      Indian Institute of Technology Dharwad
# 3057      Indian Institute of Technology Dharwad
# 3066      Indian Institute of Technology Dharwad
# 3075      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 10    Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 23    Electrical Engineering (4 Years, Bachelor of T...    AI      OPEN
# 34    Electronics and Communication Engineering (4 Y...    AI      OPEN
# ...

# %%
plt.figure(figsize=(20,20))
iit_fil_df['Opening Rank'].head(50).sort_values(inplace=True)
sns.histplot(data=iit_fil_df,x='Opening Rank',y='Institute',bins=100)
plt.yticks(rotation=45)
plt.xticks(rotation=90)
plt.show()

# %%
iit_fil_df['Opening Rank'].head(50).sort_values(inplace=True)
iit_fil_df.columns
# Out:
# Index(['Institute', 'Academic Program Name', 'Quota', 'Seat Type', 'Gender',
#        'Opening Rank', 'Closing Rank'],
#       dtype='object')
